# %%
import numpy as np
import matplotlib.pyplot as plt

X = np.linspace(0,10,200)
Y = np.sin(4*X)
img = np.tile(Y,(50,1))

plt.figure
plt.figure(figsize=(20, 10))
plt.subplot(2,1,1)
plt.plot(X,Y)
plt.subplot(2,1,2)
plt.imshow(img)
