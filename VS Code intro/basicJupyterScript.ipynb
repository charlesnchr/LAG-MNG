# %% [markdown]
# # Empty Jupyter script
#
# Demonstrating how to use jupyter in VS Code
#
# Jupyter in VS code operates in the same way as jupyter lab. We can choose between code and markdown cells

# %%
import numpy as np
from helpfulFunctions import *
import matplotlib.pyplot as plt

# %% [markdown]
# And include the same formatting features as jupyter lab
# * Bullet points
#
# Equations:
#  $$ E_i(x) = 1+m \cdot \cos(2 \pi k_0x + \phi _i)$$

# %% [markdown]
# Iff we set up some random array we an show it as normal

# %%
arr = np.random.rand(3,3)
arr
# Out:
# array([[0.18589825, 0.16350487, 0.04390402],
#        [0.91997219, 0.71562137, 0.70078071],
#        [0.00727552, 0.3939704 , 0.71152227]])

# %% [markdown]
# but we can use the active variables tab to keep track of what variables are present

# %%
path = 'peppers.png'
img = loadImage(path)

X = np.linspace(-np.pi,np.pi,250)
Y = np.cos(X)

# %% [markdown]
# And you can see the outputs from your cells as you would in jupyter lab

# %%
plt.figure(figsize=(10,5))
plt.subplot(1,2,1)
plt.imshow(img)

plt.subplot(1,2,2)
plt.plot(X,Y)
plt.show()
